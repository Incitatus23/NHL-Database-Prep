# %%
import pandas as pd
import numpy as np

# %%
playerdf = pd.read_csv('player.csv')

# %%
playerdf
# Out:
#          Rk                       Player  Age Pos   Tm  GP   G   A  PTS  \
# 0         1     Connor McDavid\mcdavco01   20   C  EDM  82  30  70  100
# 1         2      Sidney Crosby\crosbsi01   29   C  PIT  75  44  45   89
# 2         3        Patrick Kane\kanepa01   28  RW  CHI  82  34  55   89
# 3         4  Nicklas Backstrom\backsni02   29   C  WSH  82  23  63   86
# 4         5    Nikita Kucherov\kucheni01   23  RW  TBL  74  40  45   85
# ...     ...                          ...  ...  ..  ...  ..  ..  ..  ...
# 13051  2640        Peter White\whitepe01   34   C  PHI   3   0   0    0
# 13052  2641         Clarke Wilm\wilmcl01   27   C  TOR  10   0   0    0
# 13053  2642   Jeremy Yablonski\yabloje01   23  RW  STL   1   0   0    0
# 13054  2643      Nolan Yonkman\yonkmno01   22   D  WSH   1   0   0    0
# 13055  2644   Miroslav Zalesak\zalesmi01   24  RW  SJS   2   0   0    0
#
#        plusminus  ...   TOI       ATOI  BLK  HIT  FOW  FOL  FO_percent  HART  \
# ...

# %%
teams = pd.read_csv('teams.csv')

# %%
teams.head()
# Out:
#   team  season name team.1    position situation  games_played  \
# 0  WPG    2021  WPG    WPG  Team Level     other            82
# 1  WPG    2021  WPG    WPG  Team Level       all            82
# 2  WPG    2021  WPG    WPG  Team Level      5on5            82
# 3  WPG    2021  WPG    WPG  Team Level      4on5            82
# 4  WPG    2021  WPG    WPG  Team Level      5on4            82
#
#    xGoalsPercentage  corsiPercentage  fenwickPercentage  ...  \
# 0              0.49             0.50               0.47  ...
# 1              0.49             0.50               0.50  ...
# 2              0.49             0.49               0.50  ...
# 3              0.16             0.14               0.15  ...
# 4              0.86             0.86               0.85  ...
#
#    scoreAdjustedShotsAttemptsAgainst  unblockedShotAttemptsAgainst  \
# 0                             286.00                         229.0
# 1                            4795.23                        3707.0
# ...

# %%
teams2 = teams[['team', 'season', 'situation', 'goalsFor', 'penalityMinutesFor', 'hitsFor', 'faceOffsWonFor', 'goalsAgainst', 'penalityMinutesAgainst', 'hitsAgainst', 'faceOffsWonAgainst']]

# %%
teams2
# Out:
#     team  season situation  goalsFor  penalityMinutesFor  hitsFor  \
# 0    WPG    2021     other      37.0                26.0     41.0
# 1    WPG    2021       all     250.0               648.0   1921.0
# 2    WPG    2021      5on5     156.0               568.0   1766.0
# 3    WPG    2021      4on5       8.0                17.0     81.0
# 4    WPG    2021      5on4      49.0                37.0     33.0
# ..   ...     ...       ...       ...                 ...      ...
# 155  SEA    2021     other      24.0                14.0     35.0
# 156  SEA    2021       all     213.0               616.0   1771.0
# 157  SEA    2021      5on5     152.0               557.0   1622.0
# 158  SEA    2021      4on5       8.0                23.0     78.0
# 159  SEA    2021      5on4      29.0                22.0     36.0
#
#      faceOffsWonFor  goalsAgainst  penalityMinutesAgainst  hitsAgainst  \
# 0             120.0          34.0                    12.0         40.0
# ...

# %%
teams3 = teams2[teams2['situation'] == 'all']

# %%
teams3.reset_index()
# Out:
#     index team  season situation  goalsFor  penalityMinutesFor  hitsFor  \
# 0       1  WPG    2021       all     250.0               648.0   1921.0
# 1       6  CBJ    2021       all     258.0               595.0   1638.0
# 2      11  PIT    2021       all     269.0               546.0   2010.0
# 3      16  NSH    2021       all     262.0               935.0   2470.0
# 4      21  VGK    2021       all     262.0               556.0   1680.0
# 5      26  EDM    2021       all     285.0               586.0   1853.0
# 6      31  FLA    2021       all     337.0               712.0   2051.0
# 7      36  OTT    2021       all     224.0               728.0   2417.0
# 8      41  VAN    2021       all     246.0               619.0   1901.0
# 9      46  STL    2021       all     309.0               557.0   1656.0
# 10     51  PHI    2021       all     210.0               645.0   1839.0
# 11     56  DET    2021       all     227.0               641.0   1599.0
# ...

# %%
teams7 =  teams3.drop(columns=['situation'])

# %%
teams7
# Out:
#     team  season  goalsFor  penalityMinutesFor  hitsFor  faceOffsWonFor  \
# 1    WPG    2021     250.0               648.0   1921.0          2262.0
# 6    CBJ    2021     258.0               595.0   1638.0          2257.0
# 11   PIT    2021     269.0               546.0   2010.0          2361.0
# 16   NSH    2021     262.0               935.0   2470.0          2495.0
# 21   VGK    2021     262.0               556.0   1680.0          2348.0
# 26   EDM    2021     285.0               586.0   1853.0          2414.0
# 31   FLA    2021     337.0               712.0   2051.0          2364.0
# 36   OTT    2021     224.0               728.0   2417.0          2216.0
# 41   VAN    2021     246.0               619.0   1901.0          2403.0
# 46   STL    2021     309.0               557.0   1656.0          2269.0
# 51   PHI    2021     210.0               645.0   1839.0          2448.0
# 56   DET    2021     227.0               641.0   1599.0          2247.0
# ...

# %%
 teams7['season'].replace({2021:'2021-2022 '}, inplace=True)

# %%
teams7
# Out:
#     team      season  goalsFor  penalityMinutesFor  hitsFor  faceOffsWonFor  \
# 1    WPG  2021-2022      250.0               648.0   1921.0          2262.0
# 6    CBJ  2021-2022      258.0               595.0   1638.0          2257.0
# 11   PIT  2021-2022      269.0               546.0   2010.0          2361.0
# 16   NSH  2021-2022      262.0               935.0   2470.0          2495.0
# 21   VGK  2021-2022      262.0               556.0   1680.0          2348.0
# 26   EDM  2021-2022      285.0               586.0   1853.0          2414.0
# 31   FLA  2021-2022      337.0               712.0   2051.0          2364.0
# 36   OTT  2021-2022      224.0               728.0   2417.0          2216.0
# 41   VAN  2021-2022      246.0               619.0   1901.0          2403.0
# 46   STL  2021-2022      309.0               557.0   1656.0          2269.0
# 51   PHI  2021-2022      210.0               645.0   1839.0          2448.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-2f92fd0fef93> in <module>
# ----> 1 teams6['season_int'] = pd.to_string(teams6['season'])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_string'

# %%
teams7['team'].replace({'WPG': 'Jets',
                                'CBJ' : 'Blue Jackets',
                                'NSH' : 'Predators',
                                'VGK' : 'Golden Knights',
                                'EDM' : 'Oilers',
                                'FLA' : 'Panthers',
                                'OTT' : 'Senators',
                                'VAN' : 'Canucks',
                                'STL' : 'Blues',
                                'PHI' : 'Flyers',
                                'DET' : 'Red Wings',
                                'BUF' : 'Sabres',
                                'SJS' : 'Sharks',
                                'COL' : 'Avalanche',
                                'BOS': 'Bruins',
                                'NYR' : 'Rangers',
                                'MTL' : 'Canadiens',
                                'TBL' : 'Lightning',
                                'LAK' : 'Kings',
                                'ANA' : 'Ducks',
                                'CAR' : 'Hurricanes',
                                'DAL' : 'Stars',
                                'NYI' : 'Islanders',
                                'NJD' : 'Devils',
                                'WSH' : 'Capitals',
                                'CGY' : 'Flames',
                                'CHI' : 'Blackhawks',
                                'TOR': 'Maple Leafs',
                                'MIN' : 'Wild',
                                'ARI' : 'Coyotes',
                                'PIT' : 'Penguins',
                                'SEA' : 'Kraken'}, inplace=True)

# %%
teams7.reset_index()
# Out:
#     index            team      season  goalsFor  penalityMinutesFor  hitsFor  \
# 0       1            Jets  2021-2022      250.0               648.0   1921.0
# 1       6    Blue Jackets  2021-2022      258.0               595.0   1638.0
# 2      11        Penguins  2021-2022      269.0               546.0   2010.0
# 3      16       Predators  2021-2022      262.0               935.0   2470.0
# 4      21  Golden Knights  2021-2022      262.0               556.0   1680.0
# 5      26          Oilers  2021-2022      285.0               586.0   1853.0
# 6      31        Panthers  2021-2022      337.0               712.0   2051.0
# 7      36        Senators  2021-2022      224.0               728.0   2417.0
# 8      41         Canucks  2021-2022      246.0               619.0   1901.0
# 9      46           Blues  2021-2022      309.0               557.0   1656.0
# 10     51          Flyers  2021-2022      210.0               645.0   1839.0
# ...

# %%
teams7 = teams7.astype({"goalsFor":'int', "penalityMinutesFor":'int', 'hitsFor' : 'int', 'faceOffsWonFor' : 'int',
                       'goalsAgainst' : 'int', 'penalityMinutesAgainst' : 'int', 'hitsAgainst' : 'int',
                       'faceOffsWonAgainst': 'int'})

# %%
teams7
# Out:
#                team      season  goalsFor  penalityMinutesFor  hitsFor  \
# 1              Jets  2021-2022        250                 648     1921
# 6      Blue Jackets  2021-2022        258                 595     1638
# 11         Penguins  2021-2022        269                 546     2010
# 16        Predators  2021-2022        262                 935     2470
# 21   Golden Knights  2021-2022        262                 556     1680
# 26           Oilers  2021-2022        285                 586     1853
# 31         Panthers  2021-2022        337                 712     2051
# 36         Senators  2021-2022        224                 728     2417
# 41          Canucks  2021-2022        246                 619     1901
# 46            Blues  2021-2022        309                 557     1656
# 51           Flyers  2021-2022        210                 645     1839
# 56        Red Wings  2021-2022        227                 641     1599
# ...

# %%
teams7.rename(columns={'penalityMinutesFor': 'penaltyMinutesFor', 'penalityMinutesAgainst' : 'penaltyMinutesAgainst'}, 
             inplace=True)

# %%
teams7
# Out:
#                team      season  goalsFor  penaltyMinutesFor  hitsFor  \
# 1              Jets  2021-2022        250                648     1921
# 6      Blue Jackets  2021-2022        258                595     1638
# 11         Penguins  2021-2022        269                546     2010
# 16        Predators  2021-2022        262                935     2470
# 21   Golden Knights  2021-2022        262                556     1680
# 26           Oilers  2021-2022        285                586     1853
# 31         Panthers  2021-2022        337                712     2051
# 36         Senators  2021-2022        224                728     2417
# 41          Canucks  2021-2022        246                619     1901
# 46            Blues  2021-2022        309                557     1656
# 51           Flyers  2021-2022        210                645     1839
# 56        Red Wings  2021-2022        227                641     1599
# ...

# %%
teams7.to_csv('teamstats1.csv')

# %%
teamdf = pd.read_csv('teams5.csv')

# %%
teamdf.head()
# Out:
#   team  season name team.1    position situation  games_played  \
# 0  CBJ    2019  CBJ    CBJ  Team Level     other            70
# 1  CBJ    2019  CBJ    CBJ  Team Level       all            70
# 2  CBJ    2019  CBJ    CBJ  Team Level      5on5            70
# 3  CBJ    2019  CBJ    CBJ  Team Level      4on5            70
# 4  CBJ    2019  CBJ    CBJ  Team Level      5on4            70
#
#    xGoalsPercentage  corsiPercentage  fenwickPercentage  ...  \
# 0              0.50             0.43               0.44  ...
# 1              0.52             0.49               0.51  ...
# 2              0.52             0.49               0.51  ...
# 3              0.18             0.16               0.18  ...
# 4              0.81             0.86               0.85  ...
#
#    scoreAdjustedShotsAttemptsAgainst  unblockedShotAttemptsAgainst  \
# 0                             240.00                           180
# 1                            3941.01                          2868
# ...

# %%
teamdf2 = teamdf[['team', 'season', 'situation', 'goalsFor', 'penalityMinutesFor', 'hitsFor', 'faceOffsWonFor', 'goalsAgainst', 'penalityMinutesAgainst', 'hitsAgainst', 'faceOffsWonAgainst']]

# %%
teamdf3 = teamdf2[teamdf2['situation'] == 'all']

# %%
teamdf3 =  teamdf3.drop(columns=['situation'])

# %%
teamdf3['team'].replace({'WPG': 'Jets',
                                'CBJ' : 'Blue Jackets',
                                'NSH' : 'Predators',
                                'VGK' : 'Golden Knights',
                                'EDM' : 'Oilers',
                                'FLA' : 'Panthers',
                                'OTT' : 'Senators',
                                'VAN' : 'Canucks',
                                'STL' : 'Blues',
                                'PHI' : 'Flyers',
                                'DET' : 'Red Wings',
                                'BUF' : 'Sabres',
                                'S.J' : 'Sharks',
                                'COL' : 'Avalanche',
                                'BOS': 'Bruins',
                                'NYR' : 'Rangers',
                                'MTL' : 'Canadiens',
                                'T.B' : 'Lightning',
                                'L.A' : 'Kings',
                                'ANA' : 'Ducks',
                                'CAR' : 'Hurricanes',
                                'DAL' : 'Stars',
                                'NYI' : 'Islanders',
                                'N.J' : 'Devils',
                                'WSH' : 'Capitals',
                                'CGY' : 'Flames',
                                'CHI' : 'Blackhawks',
                                'TOR': 'Maple Leafs',
                                'MIN' : 'Wild',
                                'ARI' : 'Coyotes',
                                'PIT' : 'Penguins',
                                'SEA' : 'Kraken'}, inplace=True)

# %%
teamdf3 = teamdf3.astype({"goalsFor":'int', "penalityMinutesFor":'int', 'hitsFor' : 'int', 'faceOffsWonFor' : 'int',
                       'goalsAgainst' : 'int', 'penalityMinutesAgainst' : 'int', 'hitsAgainst' : 'int',
                       'faceOffsWonAgainst': 'int'})

# %%
teamdf3.rename(columns={'penalityMinutesFor': 'penaltyMinutesFor', 'penalityMinutesAgainst' : 'penaltyMinutesAgainst'}, 
             inplace=True)

# %%
teamdf3
# Out:
#                team  season  goalsFor  penaltyMinutesFor  hitsFor  \
# 1      Blue Jackets    2019       180                402     1436
# 6          Capitals    2019       236                631     1716
# 11             Jets    2019       213                457     1550
# 16           Devils    2019       185                556     1381
# 21            Kings    2019       177                457     1460
# 26         Senators    2019       190                578     1978
# 31         Penguins    2019       221                475     1883
# 36         Panthers    2019       228                464     1247
# 41           Bruins    2019       227                602     1648
# 46           Sharks    2019       180                555     1586
# 51            Stars    2019       178                510     1538
# 56           Flames    2019       204                519     1278
# 61          Coyotes    2019       190                438     1376
# ...

# %%
 teamdf3['season'].replace({2019:'2019-2020 '}, inplace=True)

# %%
teamdf3
# Out:
#                team      season  goalsFor  penaltyMinutesFor  hitsFor  \
# 1      Blue Jackets  2019-2020        180                402     1436
# 6          Capitals  2019-2020        236                631     1716
# 11             Jets  2019-2020        213                457     1550
# 16           Devils  2019-2020        185                556     1381
# 21            Kings  2019-2020        177                457     1460
# 26         Senators  2019-2020        190                578     1978
# 31         Penguins  2019-2020        221                475     1883
# 36         Panthers  2019-2020        228                464     1247
# 41           Bruins  2019-2020        227                602     1648
# 46           Sharks  2019-2020        180                555     1586
# 51            Stars  2019-2020        178                510     1538
# 56           Flames  2019-2020        204                519     1278
# ...

# %%
teamdf3.to_csv('teamstats5.csv')

# %%
playerdf
# Out:
#          Rk                       Player  Age Pos   Tm  GP   G   A  PTS  \
# 0         1     Connor McDavid\mcdavco01   20   C  EDM  82  30  70  100
# 1         2      Sidney Crosby\crosbsi01   29   C  PIT  75  44  45   89
# 2         3        Patrick Kane\kanepa01   28  RW  CHI  82  34  55   89
# 3         4  Nicklas Backstrom\backsni02   29   C  WSH  82  23  63   86
# 4         5    Nikita Kucherov\kucheni01   23  RW  TBL  74  40  45   85
# ...     ...                          ...  ...  ..  ...  ..  ..  ..  ...
# 13051  2640        Peter White\whitepe01   34   C  PHI   3   0   0    0
# 13052  2641         Clarke Wilm\wilmcl01   27   C  TOR  10   0   0    0
# 13053  2642   Jeremy Yablonski\yabloje01   23  RW  STL   1   0   0    0
# 13054  2643      Nolan Yonkman\yonkmno01   22   D  WSH   1   0   0    0
# 13055  2644   Miroslav Zalesak\zalesmi01   24  RW  SJS   2   0   0    0
#
#        plusminus  ...   TOI       ATOI  BLK  HIT  FOW  FOL  FO_percent  HART  \
# ...

# %%
playerdf2 = playerdf[['Player', 'Pos', 'Tm', 'GP', 'G', 'A', 'PTS', 'plusminus', 'PIM', 'Season']]

# %%
playerdf2
# Out:
#                             Player Pos   Tm  GP   G   A  PTS  plusminus  PIM  \
# 0         Connor McDavid\mcdavco01   C  EDM  82  30  70  100         27   26
# 1          Sidney Crosby\crosbsi01   C  PIT  75  44  45   89         17   24
# 2            Patrick Kane\kanepa01  RW  CHI  82  34  55   89         11   32
# 3      Nicklas Backstrom\backsni02   C  WSH  82  23  63   86         17   38
# 4        Nikita Kucherov\kucheni01  RW  TBL  74  40  45   85         13   38
# ...                            ...  ..  ...  ..  ..  ..  ...        ...  ...
# 13051        Peter White\whitepe01   C  PHI   3   0   0    0         -1    2
# 13052         Clarke Wilm\wilmcl01   C  TOR  10   0   0    0          0    7
# 13053   Jeremy Yablonski\yabloje01  RW  STL   1   0   0    0         -1    5
# 13054      Nolan Yonkman\yonkmno01   D  WSH   1   0   0    0          0    0
# 13055   Miroslav Zalesak\zalesmi01  RW  SJS   2   0   0    0         -1    0
#
#        Season
# 0        2017
# ...

# %%
playerdf2.Player.str.replace("(\).*","")
# Out:
# <ipython-input-6-7f588244b71b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   playerdf2.Player.str.replace("(\).*","")
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-7f588244b71b> in <module>
# ----> 1 playerdf2.Player.str.replace("(\).*","")
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in replace(self, pat, repl, n, case, flags, regex)
#    1309                 warnings.warn(msg, FutureWarning, stacklevel=3)
#    1310             regex = True
# -> 1311         result = self._data.array._str_replace(
# ...

# %%
playerdf2['Name'] = [x.split('\\')[0] for x in playerdf['Player']]
# Out:
# <ipython-input-8-bbec0ab22709>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playerdf2['Name'] = [x.split('\\')[0] for x in playerdf['Player']]

# %%
playerdf2 = playerdf2[['Name', 'Pos', 'Tm', 'GP', 'G', 'A', 'PTS', 'plusminus', 'PIM', 'Season']]

# %%
playerdf2
# Out:
#                     Name Pos   Tm  GP   G   A  PTS  plusminus  PIM  Season
# 0         Connor McDavid   C  EDM  82  30  70  100         27   26    2017
# 1          Sidney Crosby   C  PIT  75  44  45   89         17   24    2017
# 2           Patrick Kane  RW  CHI  82  34  55   89         11   32    2017
# 3      Nicklas Backstrom   C  WSH  82  23  63   86         17   38    2017
# 4        Nikita Kucherov  RW  TBL  74  40  45   85         13   38    2017
# ...                  ...  ..  ...  ..  ..  ..  ...        ...  ...     ...
# 13051        Peter White   C  PHI   3   0   0    0         -1    2    2004
# 13052        Clarke Wilm   C  TOR  10   0   0    0          0    7    2004
# 13053   Jeremy Yablonski  RW  STL   1   0   0    0         -1    5    2004
# 13054      Nolan Yonkman   D  WSH   1   0   0    0          0    0    2004
# 13055   Miroslav Zalesak  RW  SJS   2   0   0    0         -1    0    2004
#
# [13056 rows x 10 columns]

# %%
playerdf2['Tm'].replace({'WPG': 'Jets',
                                'CBJ' : 'Blue Jackets',
                                'NSH' : 'Predators',
                                'VGK' : 'Golden Knights',
                                'EDM' : 'Oilers',
                                'FLA' : 'Panthers',
                                'OTT' : 'Senators',
                                'VAN' : 'Canucks',
                                'STL' : 'Blues',
                                'PHI' : 'Flyers',
                                'DET' : 'Red Wings',
                                'BUF' : 'Sabres',
                                'SJS' : 'Sharks',
                                'COL' : 'Avalanche',
                                'BOS': 'Bruins',
                                'NYR' : 'Rangers',
                                'MTL' : 'Canadiens',
                                'TBL' : 'Lightning',
                                'LAK' : 'Kings',
                                'ANA' : 'Ducks',
                                'CAR' : 'Hurricanes',
                                'DAL' : 'Stars',
                                'NYI' : 'Islanders',
                                'NJD' : 'Devils',
                                'WSH' : 'Capitals',
                                'CGY' : 'Flames',
                                'CHI' : 'Blackhawks',
                                'TOR': 'Maple Leafs',
                                'MIN' : 'Wild',
                                'ARI' : 'Coyotes',
                                'PIT' : 'Penguins',
                                'SEA' : 'Kraken'}, inplace=True)
# Out:
# C:\Users\adaml\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
# Out:
#                     Name Pos           Tm  GP   G   A  PTS  plusminus  PIM  \
# 0         Connor McDavid   C       Oilers  82  30  70  100         27   26
# 1          Sidney Crosby   C     Penguins  75  44  45   89         17   24
# 2           Patrick Kane  RW   Blackhawks  82  34  55   89         11   32
# 3      Nicklas Backstrom   C     Capitals  82  23  63   86         17   38
# 4        Nikita Kucherov  RW    Lightning  74  40  45   85         13   38
# ...                  ...  ..          ...  ..  ..  ..  ...        ...  ...
# 13051        Peter White   C       Flyers   3   0   0    0         -1    2
# 13052        Clarke Wilm   C  Maple Leafs  10   0   0    0          0    7
# 13053   Jeremy Yablonski  RW        Blues   1   0   0    0         -1    5
# 13054      Nolan Yonkman   D     Capitals   1   0   0    0          0    0
# 13055   Miroslav Zalesak  RW       Sharks   2   0   0    0         -1    0
#
#        Season
# 0        2017
# 1        2017
# 2        2017
# ...

# %%
player2017 = playerdf2[playerdf2['Season'] == 2017]
player2016 = playerdf2[playerdf2['Season'] == 2016]
player2015 = playerdf2[playerdf2['Season'] == 2015]

# %%
player2017['Season'].replace({2017:'2016-2017 '}, inplace=True)
player2016['Season'].replace({2016:'2015-2016 '}, inplace=True) 
player2015['Season'].replace({2015:'2014-2015 '}, inplace=True)
# Out:
# C:\Users\adaml\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
player2015['Season'].replace({2015:'2014-2015 '}, inplace=True)
# Out:
# C:\Users\adaml\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %% [raw]
# player2015

# %%
player2015
# Out:
#                    Name Pos          Tm  GP   G   A  PTS  plusminus  PIM  \
# 1786         Jamie Benn  LW       Stars  82  35  52   87          1   64
# 1787       John Tavares   C   Islanders  82  38  48   86          5   46
# 1788      Sidney Crosby   C    Penguins  77  28  56   84          5   47
# 1789      Alex Ovechkin  LW    Capitals  81  53  28   81         10   58
# 1790      Jakub Voracek  RW      Flyers  82  22  59   81          1   78
# ...                 ...  ..         ...  ..  ..  ..  ...        ...  ...
# 2663         David Wolf  LW      Flames   3   0   0    0          0    2
# 2664      Brendan Woods  LW  Hurricanes   2   0   0    0         -1    0
# 2665  Tyler Wotherspoon   D      Flames   1   0   0    0         -3    0
# 2666     Bogdan Yakimov   C      Oilers   1   0   0    0         -1    0
# 2667  Harry Zolnierczyk  LW   Islanders   2   0   0    0         -1    0
#
#           Season
# 1786  2015-2016
# 1787  2015-2016
# 1788  2015-2016
# 1789  2015-2016
# ...

# %%
player_names = ['Connor McDavid', 'Leon Draisaitl', 'Zach Hyman', 'John Tavares', 'Auston Matthews', 'Mitch Marner',
        'William Nylander', 'Sidney Crosby', 'Evgeni Malkin', 'Kris Letang', 'Patrice Bergeron', 'David Pastrnak',
         'Brad Marchand', 'Gabriel Landeskog', 'Nathan Mackinnon', 'Mikko Rantenen', 'Victor Hedman', 'Steven Stamkos',
         'Brayden Point', 'Alexander Ovechkin', 'Evgeny Kuznetsov', 'Tom Wilson', 'Nicklas Backstorm']

p2017 = player2017[player2017['Name'].isin(player_names)]

# %%
p2016 = player2016[player2016['Name'].isin(player_names)]

# %%
p2015 = player2015[player2015['Name'].isin(player_names)]

# %%
p2017.reset_index()
# Out:
#     index               Name Pos           Tm  GP   G   A  PTS  plusminus  \
# 0       0     Connor McDavid   C       Oilers  82  30  70  100         27
# 1       1      Sidney Crosby   C     Penguins  75  44  45   89         17
# 2       5      Brad Marchand  LW       Bruins  80  39  46   85         18
# 3       7     Leon Draisaitl   C       Oilers  82  29  48   77          7
# 4      13      Evgeni Malkin   C     Penguins  62  33  39   72         18
# 5      15      Victor Hedman   D    Lightning  79  16  56   72          3
# 6      17     David Pastrnak  RW       Bruins  75  34  36   70         11
# 7      19    Auston Matthews   C  Maple Leafs  82  40  29   69          2
# 8      27       John Tavares   C    Islanders  77  28  38   66          4
# 9      37   William Nylander   C  Maple Leafs  81  22  39   61         -3
# 10     39       Mitch Marner   C  Maple Leafs  77  19  42   61          0
# 11     42   Evgeny Kuznetsov   C     Capitals  82  19  40   59         18
# ...

# %%
p2016
# Out:
#                    Name Pos           Tm  GP   G   A  PTS  plusminus  PIM  \
# 890       Sidney Crosby   C     Penguins  80  36  49   85         19   42
# 897    Evgeny Kuznetsov   C     Capitals  82  20  57   77         27   32
# 903        John Tavares   C    Islanders  78  33  37   70          6   38
# 905    Patrice Bergeron   C       Bruins  80  32  36   68         12   49
# 907         Kris Letang   D     Penguins  71  16  51   67          9   66
# 911      Steven Stamkos   C    Lightning  77  36  28   64          3   38
# 922       Brad Marchand  LW       Bruins  77  37  24   61         21   90
# 942       Evgeni Malkin   C     Penguins  57  27  31   58          1   65
# 962   Gabriel Landeskog  LW    Avalanche  75  20  33   53         -5   69
# 974      Leon Draisaitl   C       Oilers  72  19  32   51         -2   20
# 996      Connor McDavid   C       Oilers  45  16  32   48         -1   18
# 1001      Victor Hedman   D    Lightning  78  10  37   47         21   46
# ...

# %%
p2015
# Out:
#                    Name Pos         Tm  GP   G   A  PTS  plusminus  PIM  \
# 1787       John Tavares   C  Islanders  82  38  48   86          5   46
# 1788      Sidney Crosby   C   Penguins  77  28  56   84          5   47
# 1799     Steven Stamkos   C  Lightning  82  43  29   72          2   49
# 1803      Evgeni Malkin   C   Penguins  69  28  42   70         -2   60
# 1840  Gabriel Landeskog  LW  Avalanche  82  23  36   59         -2   79
# 1848   Patrice Bergeron   C     Bruins  81  23  32   55          2   44
# 1862        Kris Letang   D   Penguins  69  11  43   54         12   79
# 1920      Brad Marchand  LW     Bruins  77  24  18   42          5   95
# 1956      Victor Hedman   D  Lightning  59  10  28   38         12   40
# 1963   Evgeny Kuznetsov   C   Capitals  80  11  26   37         10   24
# 2056     David Pastrnak  RW     Bruins  46  10  17   27         12    8
# 2190         Tom Wilson  RW   Capitals  67   4  13   17         -1  172
# ...

# %%
p2015.to_csv('p2015.csv')
p2016.to_csv('p2016.csv')
p2017.to_csv('p2017.csv')

# %%
p2023 = pd.read_csv('p2223.csv')

p2023
# Out:
#       playerId  season           name team position situation  games_played  \
# 0      8475791    2022    Taylor Hall  BOS        L     other            37
# 1      8475791    2022    Taylor Hall  BOS        L       all            37
# 2      8475791    2022    Taylor Hall  BOS        L      5on5            37
# 3      8475791    2022    Taylor Hall  BOS        L      4on5            37
# 4      8475791    2022    Taylor Hall  BOS        L      5on4            37
# ...        ...     ...            ...  ...      ...       ...           ...
# 4135   8480468    2022  James Hamblin  EDM        L     other            10
# 4136   8480468    2022  James Hamblin  EDM        L       all            10
# 4137   8480468    2022  James Hamblin  EDM        L      5on5            10
# 4138   8480468    2022  James Hamblin  EDM        L      4on5            10
# 4139   8480468    2022  James Hamblin  EDM        L      5on4            10
#
# ...

# %%
p2023 = p2023[['season', 'name', 'situation', 'games_played', 'I_F_primaryAssists', 'I_F_secondaryAssists', 'I_F_points',
              'I_F_goals', 'I_F_penalityMinutes']]

# %%
p2023 = p2023[p2023['situation'] == 'all']

# %%
p2023
# Out:
#       season             name situation  games_played  I_F_primaryAssists  \
# 1       2022      Taylor Hall       all            37                   9
# 6       2022  Ilya Lyubushkin       all            21                   2
# 11      2022   Jared Spurgeon       all            36                   6
# 16      2022      Travis Boyd       all            35                   7
# 21      2022      Kris Letang       all            29                   5
# ...      ...              ...       ...           ...                 ...
# 4116    2022  William Carrier       all            39                   3
# 4121    2022       Tim Sttzle       all            33                   8
# 4126    2022    Lane Pederson       all             6                   2
# 4131    2022  Isac Lundestrom       all            24                   3
# 4136    2022    James Hamblin       all            10                   0
#
#       I_F_secondaryAssists  I_F_points  I_F_goals  I_F_penalityMinutes
# ...

# %%
player_names = ['Zach Hyman', 'John Tavares', 'Auston Matthews', 'Mitchell Marner',
        'William Nylander', 'Sidney Crosby', 'Evgeni Malkin', 'Kris Letang', 'Patrice Bergeron', 'David Pastrnak',
         'Brad Marchand', 'Gabriel Landeskog', 'Nathan MacKinnon', 'Mikko Rantenen', 'Victor Hedman', 'Steven Stamkos',
         'Brayden Point', 'Alex Ovechkin', 'Evgeny Kuznetsov', 'Tom Wilson', 'Nicklas Backstorm']


p2023 = p2023[p2023['name'].isin(player_names)]

p2023
# Out:
#       season              name situation  games_played  I_F_primaryAssists  \
# 21      2022       Kris Letang       all            29                   5
# 356     2022     Evgeni Malkin       all            37                  13
# 831     2022     Sidney Crosby       all            37                  14
# 866     2022     Brad Marchand       all            29                  13
# 941     2022   Mitchell Marner       all            37                  14
# 1156    2022  Nathan MacKinnon       all            25                  15
# 1506    2022   Auston Matthews       all            37                  17
# 1646    2022  William Nylander       all            37                  13
# 1651    2022    Steven Stamkos       all            35                  15
# 1901    2022        Zach Hyman       all            37                  12
# 2076    2022  Patrice Bergeron       all            37                   8
# ...

# %%
 p2023['season'].replace({2022:'2022-2023 '}, inplace=True)
# Out:
# C:\Users\adaml\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
p2023
# Out:
#           season              name situation  games_played  \
# 21    2022-2023        Kris Letang       all            29
# 356   2022-2023      Evgeni Malkin       all            37
# 831   2022-2023      Sidney Crosby       all            37
# 866   2022-2023      Brad Marchand       all            29
# 941   2022-2023    Mitchell Marner       all            37
# 1156  2022-2023   Nathan MacKinnon       all            25
# 1506  2022-2023    Auston Matthews       all            37
# 1646  2022-2023   William Nylander       all            37
# 1651  2022-2023     Steven Stamkos       all            35
# 1901  2022-2023         Zach Hyman       all            37
# 2076  2022-2023   Patrice Bergeron       all            37
# 2151  2022-2023       John Tavares       all            37
# 2166  2022-2023      Alex Ovechkin       all            39
# 2666  2022-2023      Brayden Point       all            35
# 2711  2022-2023     David Pastrnak       all            37
# ...

# %%
p2018.to_csv('p2018.csv')

# %%
p2023['Assists'] = (p2023['I_F_primaryAssists'] + p2023['I_F_secondaryAssists'])
# Out:
# <ipython-input-9-c1783f71617f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2023['Assists'] = (p2023['I_F_primaryAssists'] + p2023['I_F_secondaryAssists'])

# %%
p2023 = p2023.drop(columns=['I_F_primaryAssists', 'I_F_secondaryAssists', 'situation'])

# %%
p2023
# Out:
#           season              name  games_played  I_F_points  I_F_goals  \
# 21    2022-2023        Kris Letang            29          16          2
# 356   2022-2023      Evgeni Malkin            37          34         12
# 831   2022-2023      Sidney Crosby            37          43         19
# 866   2022-2023      Brad Marchand            29          31         10
# 941   2022-2023    Mitchell Marner            37          42         14
# 1156  2022-2023   Nathan MacKinnon            25          36          9
# 1506  2022-2023    Auston Matthews            37          42         18
# 1646  2022-2023   William Nylander            37          42         21
# 1651  2022-2023     Steven Stamkos            35          41         17
# 1901  2022-2023         Zach Hyman            37          40         17
# 2076  2022-2023   Patrice Bergeron            37          30         15
# 2151  2022-2023       John Tavares            37          34         15
# ...

# %%
p2023.to_csv('p2023.csv')
