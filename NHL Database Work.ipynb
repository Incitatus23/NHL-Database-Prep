# %%
# standard imports
import pandas as pd
import numpy as np

# %%
gamedf = pd.read_csv('GameData.csv')
gamedf
# Out:
#           game_id    season type         date_time_GMT  away_team_id  \
# 0      2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1      2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2      2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3      2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4      2017020586  20172018    R  2017-12-30T03:00:00Z            20
# ...           ...       ...  ...                   ...           ...
# 26300  2018030415  20182019    P  2019-06-07T00:00:00Z            19
# 26301  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26302  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26303  2018030417  20182019    P  2019-06-13T00:00:00Z            19
# 26304  2018030417  20182019    P  2019-06-13T00:00:00Z            19
#
#        home_team_id  away_goals  home_goals       outcome  \
# 0                16           4           7  home win REG
# ...

# %%
playerdf = pd.read_csv('PlayerData.csv')
playerdf
# Out:
#         Rk                       Player  Age Pos   Tm  GP   G   A  PTS  \
# 0        1     Connor McDavid\mcdavco01   20   C  EDM  82  30  70  100
# 1        2      Sidney Crosby\crosbsi01   29   C  PIT  75  44  45   89
# 2        3        Patrick Kane\kanepa01   28  RW  CHI  82  34  55   89
# 3        4  Nicklas Backstrom\backsni02   29   C  WSH  82  23  63   86
# 4        5    Nikita Kucherov\kucheni01   23  RW  TBL  74  40  45   85
# ...    ...                          ...  ...  ..  ...  ..  ..  ..  ...
# 13181  886       Zach Trotman\trotmza01   27   D  PIT   3   0   0    0
# 13182  887    Dominic Turgeon\turgedo01   21   C  DET   5   0   0    0
# 13183  888       Rinat Valiev\valieri01   22   D  MTL   2   0   0    0
# 13184  889         Curtis Valk\valkcu01   24  LW  FLA   1   0   0    0
# 13185  890    Zach Whitecloud\whiteza01   21   D  VEG   1   0   0    0
#
#        plusminus  ...   TOI       ATOI   BLK  HIT    FOW    FOL  FO_percent  \
# ...

# %%
teamdf = pd.read_csv('TeamInfo.csv')
teamdf
# Out:
#     team_id  franchiseId     shortName        teamName abbreviation  \
# 0         1           23    New Jersey          Devils          NJD
# 1         4           16  Philadelphia          Flyers          PHI
# 2        26           14   Los Angeles           Kings          LAK
# 3        14           31     Tampa Bay       Lightning          TBL
# 4         6            6        Boston          Bruins          BOS
# 5         3           10    NY Rangers         Rangers          NYR
# 6         5           17    Pittsburgh        Penguins          PIT
# 7        17           12       Detroit       Red Wings          DET
# 8        28           29      San Jose          Sharks          SJS
# 9        18           34     Nashville       Predators          NSH
# 10       23           20     Vancouver         Canucks          VAN
# 11       16           11       Chicago      Blackhawks          CHI
# 12        9           30        Ottawa        Senators          OTT
# ...

# %%
teamdf4 = teamdf[['shortName', 'teamName']]

teamdf4
# Out:
#        shortName        teamName
# 0     New Jersey          Devils
# 1   Philadelphia          Flyers
# 2    Los Angeles           Kings
# 3      Tampa Bay       Lightning
# 4         Boston          Bruins
# 5     NY Rangers         Rangers
# 6     Pittsburgh        Penguins
# 7        Detroit       Red Wings
# 8       San Jose          Sharks
# 9      Nashville       Predators
# 10     Vancouver         Canucks
# 11       Chicago      Blackhawks
# 12        Ottawa        Senators
# 13      Montreal       Canadiens
# 14     Minnesota            Wild
# 15    Washington        Capitals
# 16      St Louis           Blues
# 17       Anaheim           Ducks
# 18       Phoenix         Coyotes
# 19  NY Islanders       Islanders
# 20       Toronto     Maple Leafs
# 21       Florida        Panthers
# 22       Buffalo          Sabres
# 23       Calgary          Flames
# 24      Colorado       Avalanche
# 25        Dallas           Stars
# 26      Columbus    Blue Jackets
# ...

# %%
teamdf4 = teamdf4.rename(columns={'shortName': 'City', 'teamName': 'Mascot'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-98be1eca46a2> in <module>
# ----> 1 teamdf4 = teamdf4.rename(columns={'shortName': 'City', 'teamName': 'Mascot'})
#
# TypeError: rename() got an unexpected keyword argument 'columns'

# %%
teamdf4
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5       NY Rangers
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19    NY Islanders
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# 32         Atlanta
# Name: City, dtype: object

# %%
teamdf3
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5       NY Rangers
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19    NY Islanders
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# 32         Atlanta
# Name: City, dtype: object

# %% [markdown]
# teamdf4= teamdf4['City'].replace({'NY': 'New York'})

# %%
teamdf4
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5       NY Rangers
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19    NY Islanders
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# 32         Atlanta
# Name: City, dtype: object

# %%
teamdf3
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5       NY Rangers
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19    NY Islanders
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# 32         Atlanta
# Name: City, dtype: object

# %%
teamdf3 = teamdf3.replace(['NY Rangers', 'NY Islanders'],'New York')

# %%
teamdf3
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5         New York
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19        New York
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# 32         Atlanta
# Name: City, dtype: object

# %%
teamdf3 = teamdf3.drop(teamdf3.index[32])

# %%
teamdf2 =  teamdf2.drop(teamdf2.index[[3, 4, 6, 15, 20, 24, 28]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-24eed87f09e9> in <module>
# ----> 1 teamdf2 =  teamdf2.drop(teamdf2.index[[3, 4, 6, 15, 20, 24, 28]])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4305             key = np.asarray(key, dtype=bool)
#    4306
# -> 4307         result = getitem(key)
#    4308         if not is_scalar(result):
#    4309             if np.ndim(result) > 1:
#
# IndexError: index 28 is out of bounds for axis 0 with size 25

# %%
teamdf2 = teamdf2.reset_index()

# %%
teamdf3
# Out:
# 0       New Jersey
# 1     Philadelphia
# 2      Los Angeles
# 3        Tampa Bay
# 4           Boston
# 5         New York
# 6       Pittsburgh
# 7          Detroit
# 8         San Jose
# 9        Nashville
# 10       Vancouver
# 11         Chicago
# 12          Ottawa
# 13        Montreal
# 14       Minnesota
# 15      Washington
# 16        St Louis
# 17         Anaheim
# 18         Phoenix
# 19        New York
# 20         Toronto
# 21         Florida
# 22         Buffalo
# 23         Calgary
# 24        Colorado
# 25          Dallas
# 26        Columbus
# 27        Winnipeg
# 28        Edmonton
# 29           Vegas
# 30        Carolina
# 31         Arizona
# Name: City, dtype: object

# %%
teamdf2 = teamdf2[['City', 'Mascot']]

# %% [markdown]
# ##

# %%
teamdf2
# Out:
#             City          Mascot
# 0     New Jersey          Devils
# 1   Philadelphia          Flyers
# 2    Los Angeles           Kings
# 3       New York         Rangers
# 4        Detroit       Red Wings
# 5       San Jose          Sharks
# 6      Nashville       Predators
# 7      Vancouver         Canucks
# 8        Chicago      Blackhawks
# 9         Ottawa        Senators
# 10      Montreal       Canadiens
# 11     Minnesota            Wild
# 12      St Louis           Blues
# 13       Anaheim           Ducks
# 14       Phoenix         Coyotes
# 15      New York       Islanders
# 16       Florida        Panthers
# 17       Buffalo          Sabres
# 18       Calgary          Flames
# 19        Dallas           Stars
# 20      Columbus    Blue Jackets
# 21      Winnipeg            Jets
# 22         Vegas  Golden Knights
# 23      Carolina      Hurricanes
# 24       Arizona         Coyotes

# %%
teamdf3.to_csv('teamdata3.csv')

# %%
playerdf
# Out:
#         Rk                       Player  Age Pos   Tm  GP   G   A  PTS  \
# 0        1     Connor McDavid\mcdavco01   20   C  EDM  82  30  70  100
# 1        2      Sidney Crosby\crosbsi01   29   C  PIT  75  44  45   89
# 2        3        Patrick Kane\kanepa01   28  RW  CHI  82  34  55   89
# 3        4  Nicklas Backstrom\backsni02   29   C  WSH  82  23  63   86
# 4        5    Nikita Kucherov\kucheni01   23  RW  TBL  74  40  45   85
# ...    ...                          ...  ...  ..  ...  ..  ..  ..  ...
# 13181  886       Zach Trotman\trotmza01   27   D  PIT   3   0   0    0
# 13182  887    Dominic Turgeon\turgedo01   21   C  DET   5   0   0    0
# 13183  888       Rinat Valiev\valieri01   22   D  MTL   2   0   0    0
# 13184  889         Curtis Valk\valkcu01   24  LW  FLA   1   0   0    0
# 13185  890    Zach Whitecloud\whiteza01   21   D  VEG   1   0   0    0
#
#        plusminus  ...   TOI       ATOI   BLK  HIT    FOW    FOL  FO_percent  \
# ...

# %%
gamedf
# Out:
#           game_id    season type         date_time_GMT  away_team_id  \
# 0      2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1      2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2      2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3      2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4      2017020586  20172018    R  2017-12-30T03:00:00Z            20
# ...           ...       ...  ...                   ...           ...
# 26300  2018030415  20182019    P  2019-06-07T00:00:00Z            19
# 26301  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26302  2018030416  20182019    P  2019-06-10T00:00:00Z             6
# 26303  2018030417  20182019    P  2019-06-13T00:00:00Z            19
# 26304  2018030417  20182019    P  2019-06-13T00:00:00Z            19
#
#        home_team_id  away_goals  home_goals       outcome  \
# 0                16           4           7  home win REG
# ...

# %%
gamedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 26305 non-null  int64
#  1   season                  26305 non-null  int64
#  2   type                    26305 non-null  object
#  3   date_time_GMT           26305 non-null  object
#  4   away_team_id            26305 non-null  int64
#  5   home_team_id            26305 non-null  int64
#  6   away_goals              26305 non-null  int64
#  7   home_goals              26305 non-null  int64
#  8   outcome                 26305 non-null  object
#  9   home_rink_side_start    25109 non-null  object
#  10  venue                   26305 non-null  object
#  11  venue_link              26305 non-null  object
#  12  venue_time_zone_id      26305 non-null  object
#  13  venue_time_zone_offset  26305 non-null  int64
# ...

# %%
gamedf
# Out:
#           game_id    season type             date_time_GMT  away_team_id  \
# 0      2016020045  20162017    R 2016-10-19 00:30:00+00:00             4
# 1      2017020812  20172018    R 2018-02-07 00:00:00+00:00            24
# 2      2015020314  20152016    R 2015-11-24 01:00:00+00:00            21
# 3      2015020849  20152016    R 2016-02-17 00:00:00+00:00            52
# 4      2017020586  20172018    R 2017-12-30 03:00:00+00:00            20
# ...           ...       ...  ...                       ...           ...
# 26300  2018030415  20182019    P 2019-06-07 00:00:00+00:00            19
# 26301  2018030416  20182019    P 2019-06-10 00:00:00+00:00             6
# 26302  2018030416  20182019    P 2019-06-10 00:00:00+00:00             6
# 26303  2018030417  20182019    P 2019-06-13 00:00:00+00:00            19
# 26304  2018030417  20182019    P 2019-06-13 00:00:00+00:00            19
#
#        home_team_id  away_goals  home_goals       outcome  \
# ...

# %%
gamedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 26305 non-null  int64
#  1   season                  26305 non-null  int64
#  2   type                    26305 non-null  object
#  3   date_time_GMT           26305 non-null  datetime64[ns, UTC]
#  4   away_team_id            26305 non-null  int64
#  5   home_team_id            26305 non-null  int64
#  6   away_goals              26305 non-null  int64
#  7   home_goals              26305 non-null  int64
#  8   outcome                 26305 non-null  object
#  9   home_rink_side_start    25109 non-null  object
#  10  venue                   26305 non-null  object
#  11  venue_link              26305 non-null  object
#  12  venue_time_zone_id      26305 non-null  object
#  13  venue_time_zone_offset  26305 non-null  int64
# ...

# %%
gamedf['gamedate'] = gamedf['date_time_GMT'].dt.date

# %% [raw]
# gamedf2 = gamedf[[away_goals, home_goals, ]]
